# %% [markdown]
# # Лабораторная работа 4. Подбор параметров и работа с данными

# %% [markdown]
# ## Линейная регрессия

# %%
# %pylab inline

import seaborn as sns
sns.set(style="whitegrid")

from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def pairplot(df, target):
    ncol, nrow = 7, df.shape[1] // 7 + (df.shape[1] % 7 > 0)
    plt.figure(figsize=(ncol * 4, nrow * 4))

    for i, feature in enumerate(df.columns):
        plt.subplot(nrow, ncol, i + 1)
        plt.scatter(df[feature], target, s=10, marker='o', alpha=.6)
        plt.xlabel(feature)
        if i % ncol == 0:
            plt.ylabel('target')

# %% [markdown]
# В данном задании мы рассмотрим стандартный датасет для задачи регрессии Boston Housing, в котором необходимо предсказать стоимость недвижимости по 13 признакам.
#
# Датасет достаточно просто загрузить из библиотеки scikit-learn:

# %%
data = datasets.load_boston()
df = pd.DataFrame(data.data)
df.columns = data.feature_names
y = data.target

# %%
print(data['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# Разделим выборку на обучающую и тестовую в отношении 8/2:

# %%
x_train, x_test, y_train, y_test = train_test_split(df, y, train_size=0.8, random_state=42)

# %% [markdown]
# __Задание 1.__ Обучение линейной регрессии.
#
# Обучите стандартную линейную регрессию, а также с $L_1$ и $L_2$ регуляризаторами (используйте параметры по умолчанию). Посчитайте метрику $R^2$ для каждого метода (метод `score`).

# %% [markdown]
# ### LinearRegression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(x_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 24.291119474973456

# %%
lin_reg.score(x_test, y_test)
# Out:
# 0.6687594935356329

# %% [markdown]
# ### Lasso

# %%
reg_lasso = Lasso()

# %%
reg_lasso.fit(x_train, y_train)
# Out:
# Lasso()

# %%
y_pred = reg_lasso.predict(x_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 24.4094897612997

# %%
reg_lasso.score(x_test, y_test)
# Out:
# 0.6671453631686304

# %% [markdown]
# ### Ridge

# %%
reg_ridge = Ridge()

# %%
reg_ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
y_pred = reg_ridge.predict(x_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 24.477191227708683

# %%
reg_ridge.score(x_test, y_test)
# Out:
# 0.6662221670168518

# %% [markdown]
# __Задание 2.__ Подбор гиперпараметров.
#
# Для Lasso- и Ridge-регресий подберите коэффициент регуляризации по обучающей выборке с помощью кросс-валидации. Параметры для перебора возьмите по логарифмической сетке от $10^{-6}$ до $10^6$).
# Также посчитайте метрику $R^2$ для тестовой выборки и сравните с предыдущими результатами. Заметно ли изменилось качество?
#
# Useful: GridSearchCV, RidgeCV, LassoCV

# %% [markdown]
# ### Lasso

# %%
from sklearn.model_selection import GridSearchCV

# %%
alphas = np.log(10**np.linspace(-6,6,100))

# %%
grid = {'alpha': alphas}

# %%
lassoCV = GridSearchCV(Lasso(), grid, scoring='r2', cv = 5, return_train_score=True)

# %%
lassoCV.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4265.144561787798, tolerance: 2.764448730650155
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12551.909085937457, tolerance: 2.8821090464396293
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9510.855403484808, tolerance: 2.764448730650155
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11283.58447035049, tolerance: 2.710494922600619
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11851.328184868587, tolerance: 2.729756922600619
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11600.63476091089, tolerance: 2.9476950246913587
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': array([-13.81551056, -13.53640933, -13.25730811, -12.97820689,
#        -12.69910566, -12.42000444, -12.14090322, -11.86180199,
#        -11.58270077, -11.30359955, -11.02449832, -10.7453971 ,
#        -10.46629588, -10.18719465,  -9.90809343,  -9.62899221,
#         -9.34989098,  -9.07078976,  -8.79168854,  -8.51258731,
#         -8.23348609,  -7.95438487,  -7.6752836...
#          6.27977753,   6.55887875,   6.83797997,   7.1170812 ,
#          7.39618242,   7.67528364,   7.95438487,   8.23348609,
#          8.51258731,   8.79168854,   9.07078976,   9.34989098,
#          9.62899221,   9.90809343,  10.18719465,  10.46629588,
#         10.7453971 ,  11.02449832,  11.30359955,  11.58270077,
#         11.86180199,  12.14090322,  12.42000444,  12.69910566,
#         12.97820689,  13.25730811,  13.53640933,  13.81551056])},
#              return_train_score=True, scoring='r2')

# %%
lassoCV.best_params_
# Out:
# {'alpha': 0.13955061169660865}

# %%
best_score = lassoCV.best_score_
best_score
# Out:
# 0.7078936368519757

# %%
best_index = lassoCV.best_index_

# %%
df = pd.DataFrame.from_dict(lassoCV.cv_results_)

# %%
plt.figure(figsize=(20, 20))
ax = plt.gca()

plt.plot(df['param_alpha'], df['mean_test_score'], label='Тестовые значения')
plt.plot(df['param_alpha'], df['mean_train_score'], label='Тренировочные значения')


plt.scatter(df['param_alpha'][best_index], df['mean_test_score'][best_index])


# Annotate the best score for that scorer
ax.annotate("%0.4f" % best_score, (df['param_alpha'][best_index] + 0.3, best_score))

plt.legend()
plt.title("График R2 в зависимости от коэффициента регуляризации")
plt.show()

# %%
plt.figure(figsize=(13, 13))
ax = plt.gca()
ax.set_xlim(-5, 15)
ax.set_ylim(0, 1)


plt.plot(df['param_alpha'], df['mean_test_score'], label='Тестовые значения')
plt.plot(df['param_alpha'], df['mean_train_score'], label='Тренировочные значения')


plt.scatter(df['param_alpha'][best_index], df['mean_test_score'][best_index])


# Annotate the best score for that scorer
ax.annotate("%0.4f" % best_score, (df['param_alpha'][best_index] + 0.3, best_score))

plt.legend()
plt.title("График R2 в зависимости от коэффициента регуляризации")
plt.show()

# %% [markdown]
# ### Ridge

# %%
ridgeCV = GridSearchCV(Ridge(), grid, scoring='r2', cv = 5, return_train_score=True)

# %%
ridgeCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': array([-13.81551056, -13.53640933, -13.25730811, -12.97820689,
#        -12.69910566, -12.42000444, -12.14090322, -11.86180199,
#        -11.58270077, -11.30359955, -11.02449832, -10.7453971 ,
#        -10.46629588, -10.18719465,  -9.90809343,  -9.62899221,
#         -9.34989098,  -9.07078976,  -8.79168854,  -8.51258731,
#         -8.23348609,  -7.95438487,  -7.6752836...
#          6.27977753,   6.55887875,   6.83797997,   7.1170812 ,
#          7.39618242,   7.67528364,   7.95438487,   8.23348609,
#          8.51258731,   8.79168854,   9.07078976,   9.34989098,
#          9.62899221,   9.90809343,  10.18719465,  10.46629588,
#         10.7453971 ,  11.02449832,  11.30359955,  11.58270077,
#         11.86180199,  12.14090322,  12.42000444,  12.69910566,
#         12.97820689,  13.25730811,  13.53640933,  13.81551056])},
#              return_train_score=True, scoring='r2')

# %%
ridgeCV.best_estimator_
# Out:
# Ridge(alpha=-0.1395506116966087)

# %%
ridgeCV.estimator
# Out:
# Ridge()

# %%
best_score = ridgeCV.best_score_
best_score
# Out:
# 0.724563939400415

# %%
best_index = ridgeCV.best_index_

# %%
df = pd.DataFrame.from_dict(ridgeCV.cv_results_)
df1 = df[['mean_test_score', 'mean_train_score', 'param_alpha']]

# %%
df.mean_test_score.values
# Out:
# array([  0.64344809,   0.65189881,   0.65880931,   0.66453595,
#          0.66933659,   0.67340166,   0.6768744 ,   0.67986423,
#          0.68245597,   0.68471617,   0.68669764,   0.68844268,
#          0.68998549,   0.69135396,   0.6925709 ,   0.69365515,
#          0.69462227,   0.69548518,   0.69625459,   0.69693936,
#          0.69754675,   0.69808268,   0.69855183,   0.69895775,
#          0.69930295,   0.69958888,   0.6998159 ,   0.69998323,
#          0.70008874,   0.70012876,   0.70009765,   0.69998727,
#          0.69978614,   0.69947815,   0.69904057,   0.69844083,
#          0.69763126,   0.69653979,   0.695053  ,   0.69298277,
#          0.68999484,   0.68543797,   0.67786827,   0.66339535,
#          0.62737785,   0.44872902, -27.40628475,   0.66038431,
#          0.72021402,   0.72456394,   0.72394684,   0.72270719,
#          0.72153165,   0.72052961,   0.71969517,   0.71900116,
#          0.71842051,   0.71793071,   0.7175139 ,   0.71715615,
#          0.71684654,   0.71657653,   0.7163393 ,   0.71612945,
#          0.71594259,   0.71577516,   0.71562426,   0.71548746,
#          0.71536276,   0.7152485 ,   0.71514324,   0.7150458 ,
#          0.71495515,   0.71487042,   0.71479087,   0.71471583,
#          0.71464477,   0.71457717,   0.71451263,   0.71445076,
#          0.71439124,   0.71433379,   0.71427814,   0.71422408,
#          0.71417141,   0.71411994,   0.71406953,   0.71402003,
#          0.71397132,   0.71392329,   0.71387584,   0.71382887,
#          0.71378232,   0.7137361 ,   0.71369016,   0.71364444,
#          0.71359888,   0.71355343,   0.71350807,   0.71346274])

# %%
df.mean_test_score.min()
# Out:
# -27.406284752538625

# %%
df.params[46]
# Out:
# {'alpha': -0.9768542818762609}

# %%
results = ridgeCV.cv_results_

# %%
plt.figure(figsize=(15, 15))
ax = plt.gca()

plt.plot(df['param_alpha'], df['mean_test_score'], label='Тестовые значения')
plt.plot(df['param_alpha'], df['mean_train_score'], label='Тренировочные значения')


plt.scatter(df['param_alpha'][best_index], df['mean_test_score'][best_index])


# Annotate the best score for that scorer
ax.annotate("%0.4f" % best_score, (df['param_alpha'][best_index] + 0.3, best_score))

plt.legend()
plt.title("График R2 в зависимости от коэффициента регуляризации")
plt.show()

# %%
plt.figure(figsize=(13, 13))
ax = plt.gca()
ax.set_xlim(-5, 5)
ax.set_ylim(0, 1)


plt.plot(df['param_alpha'], df['mean_test_score'], label='Тестовые значения')
plt.plot(df['param_alpha'], df['mean_train_score'], label='Тренировочные значения')


plt.scatter(df['param_alpha'][best_index], df['mean_test_score'][best_index])


# Annotate the best score for that scorer
ax.annotate("%0.4f" % best_score, (df['param_alpha'][best_index] + 0.3, best_score))

plt.legend()
plt.title("График R2 в зависимости от коэффициента регуляризации")
plt.show()

# %% [markdown]
# Постройте график зависимости $R^2$ для обучающей и тестовой (на кросс-валидации) выборок в зависимости от значения гиперпараметра. Для Lasso также постройте график зависимости количества ненулевых весов.

# %% [markdown]
# В какой момент происходит недообучение? Почему?

# %% [markdown]
# __Ответ__:

# %% [markdown]
# ---

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Как вы могли заметить, большого прироста качества с помощью подбора коэфициента регуляризации добиться не удалось. Поэтому прежде чем бросаться обучать модели, необходимо изучить и предобработать данные.

# %% [markdown]
# __Задание 3.__ Масштабирование.
#
# Зачастую признаки в сырых данных имеют разный масштаб. Попробуйте применить масштабирование к данным, сравните качество. Заметно ли изменение?
#
# Pipeline, StandardScaler, MinMaxScaler

# %% [markdown]
# ### StandartScale

# %%
from sklearn.preprocessing import StandardScaler

# %%
columns = x_train.columns

# %%
scaler = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(x_train)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=columns)

# %%
X_train_scaled.head(10)
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0  1.287702 -0.500320  1.033237 -0.278089  0.489252 -1.428069  1.028015
# 1 -0.336384 -0.500320 -0.413160 -0.278089 -0.157233 -0.680087 -0.431199
# 2 -0.403253  1.013271 -0.715218 -0.278089 -1.008723 -0.402063 -1.618599
# 3  0.388230 -0.500320  1.033237 -0.278089  0.489252 -0.300450  0.591681
# 4 -0.325282 -0.500320 -0.413160 -0.278089 -0.157233 -0.831094  0.033747
# 5 -0.385519 -0.500320 -0.523527 -0.278089 -0.540021  0.162452 -1.926178
# 6 -0.402695 -0.500320 -0.841560 -0.278089 -0.352880 -0.393595 -1.218030
# 7 -0.404845  3.175545 -1.487791 -0.278089 -1.246051  0.094710 -1.175112
# 8  1.305053 -0.500320  1.033237 -0.278089  1.561057 -0.231297  1.124581
# 9  1.221694 -0.500320  1.033237 -0.278089  0.344643  0.756603  1.124581
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT
# 0 -0.802173  1.706891  1.578434  0.845343 -0.074337  1.753505
# 1  0.324349 -0.624360 -0.584648  1.204741  0.430184 -0.561474
# 2  1.330697 -0.974048 -0.602724 -0.637176  0.065297 -0.651595
# 3 -0.839240  1.706891  1.578434  0.845343 -3.868193  1.525387
# 4 -0.005494 -0.624360 -0.584648  1.204741  0.379119 -0.165787
# 5  0.755292 -0.507797 -0.705154  0.575794  0.408971 -1.038833
# 6  1.022793 -0.507797 -1.084748  0.845343  0.444180 -0.626249
# 7  2.527219 -0.857485 -0.548496 -0.457477  0.444180 -0.941672
# 8 -0.889790  1.706891  1.578434  0.845343 -3.793837  1.970358
# 9 -1.100587  1.706891  1.578434  0.845343 -1.934525  1.031130

# %%
X_test_scaled = scaler.transform(x_test)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=columns)

# %%
y_train = pd.DataFrame(y_train)

# %%
ridgeCV = GridSearchCV(Ridge(), grid, scoring='r2', cv = 5, return_train_score=True)

# %%
ridgeCV.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': array([-13.81551056, -13.53640933, -13.25730811, -12.97820689,
#        -12.69910566, -12.42000444, -12.14090322, -11.86180199,
#        -11.58270077, -11.30359955, -11.02449832, -10.7453971 ,
#        -10.46629588, -10.18719465,  -9.90809343,  -9.62899221,
#         -9.34989098,  -9.07078976,  -8.79168854,  -8.51258731,
#         -8.23348609,  -7.95438487,  -7.6752836...
#          6.27977753,   6.55887875,   6.83797997,   7.1170812 ,
#          7.39618242,   7.67528364,   7.95438487,   8.23348609,
#          8.51258731,   8.79168854,   9.07078976,   9.34989098,
#          9.62899221,   9.90809343,  10.18719465,  10.46629588,
#         10.7453971 ,  11.02449832,  11.30359955,  11.58270077,
#         11.86180199,  12.14090322,  12.42000444,  12.69910566,
#         12.97820689,  13.25730811,  13.53640933,  13.81551056])},
#              return_train_score=True, scoring='r2')

# %%
ridgeCV.best_estimator_
# Out:
# Ridge(alpha=2.9305628456287867)

# %%
best_score = ridgeCV.best_score_
best_score
# Out:
# 0.7245659789067738

# %% [markdown]
# ### MinMax

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max = MinMaxScaler()

# %%
min_max.fit(x_train)
# Out:
# MinMaxScaler()

# %%
X_train_min_max = min_max.transform(x_train)

# %%
X_train_min_max = pd.DataFrame(X_train_min_max, columns=columns)

# %%
X_train_min_max
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.168763  0.00  0.642963   0.0  0.471193  0.293065  0.972194  0.088307
# 1    0.006950  0.00  0.274074   0.0  0.314815  0.400854  0.552008  0.306359
# 2    0.000288  0.35  0.197037   0.0  0.108848  0.440919  0.210093  0.501150
# 3    0.079146  0.00  0.642963   0.0  0.471193  0.455562  0.846550  0.081132
# 4    0.008056  0.00  0.274074   0.0  0.314815  0.379093  0.685891  0.242514
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 399  0.001822  0.00  0.289630   0.0  0.277778  0.401261  0.916581  0.098337
# 400  0.003261  0.20  0.230370   0.0  0.162551  0.405328  0.403708  0.300030
# 401  0.000067  0.80  0.047037   0.0  0.102881  0.563758  0.276004  0.656039
# 402  0.125342  0.00  0.642963   0.0  0.730453  0.562538  0.944387  0.090489
# 403  0.002469  0.00  0.289630   0.0  0.277778  0.516982  0.849640  0.144141
#
#           RAD       TAX   PTRATIO         B     LSTAT
# 0    1.000000  0.914122  0.808511  0.880428  0.639625
# 1    0.130435  0.229008  0.893617  0.996772  0.185982
# 2    0.000000  0.223282  0.457447  0.912628  0.168322
# 3    1.000000  0.914122  0.808511  0.005547  0.594923
# 4    0.130435  0.229008  0.893617  0.984997  0.263521
# ..        ...       ...       ...       ...       ...
# 399  0.173913  0.375954  0.882979  0.996898  0.467163
# 400  0.086957  0.068702  0.638298  0.979197  0.310982
# 401  0.130435  0.177481  0.468085  0.984972  0.117550
# 402  1.000000  0.914122  0.808511  0.276186  0.594371
# 403  0.173913  0.375954  0.882979  0.177720  0.245585
#
# [404 rows x 13 columns]

# %%
X_test_min_max = min_max.transform(x_test)

# %%
X_test_min_max = pd.DataFrame(X_test_min_max, columns=columns)

# %%
ridgeCV = GridSearchCV(Ridge(), grid, scoring='r2', cv = 5, return_train_score=True)

# %%
ridgeCV.fit(X_train_min_max, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': array([-13.81551056, -13.53640933, -13.25730811, -12.97820689,
#        -12.69910566, -12.42000444, -12.14090322, -11.86180199,
#        -11.58270077, -11.30359955, -11.02449832, -10.7453971 ,
#        -10.46629588, -10.18719465,  -9.90809343,  -9.62899221,
#         -9.34989098,  -9.07078976,  -8.79168854,  -8.51258731,
#         -8.23348609,  -7.95438487,  -7.6752836...
#          6.27977753,   6.55887875,   6.83797997,   7.1170812 ,
#          7.39618242,   7.67528364,   7.95438487,   8.23348609,
#          8.51258731,   8.79168854,   9.07078976,   9.34989098,
#          9.62899221,   9.90809343,  10.18719465,  10.46629588,
#         10.7453971 ,  11.02449832,  11.30359955,  11.58270077,
#         11.86180199,  12.14090322,  12.42000444,  12.69910566,
#         12.97820689,  13.25730811,  13.53640933,  13.81551056])},
#              return_train_score=True, scoring='r2')

# %%
ridgeCV.best_estimator_
# Out:
# Ridge(alpha=0.4186518350898262)

# %%
best_score = ridgeCV.best_score_
best_score
# Out:
# 0.7252514400076074

# %% [markdown]
# __Задание 4.__ Новые признаки.
#
# Полезным также бывает посмотреть как целевая переменная зависит от каждого признака.

# %%
x_train_log = x_train.copy()

# %%
x_test_log = x_test.copy()

# %%
x_train_log.LSTAT = np.log(x_train_log.LSTAT)

# %%
x_test_log.LSTAT = np.log(x_test_log.LSTAT)

# %%
pairplot(x_train, y_train)

# %%
pairplot(x_train_log, y_train)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train_log, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(x_test_log)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 18.697896839987212

# %%
lin_reg.score(x_test_log, y_test)
# Out:
# 0.7450302434403294

# %% [markdown]
# Обратите внимение на зависимость цены от признака LSTAT. Является ли эта зависимость линейной? А какой? Попробуйте выбрать преобразование для этого признака так, чтобы получившаяся зависимость была более линейной. Добейтесь $R^2$ на тестовой выборке не меньше 0.71.

# %% [markdown]
# __Ответ:__

# %% [markdown]
# Помимо преобразований отдельных признаков полезными бывают их попарные взаимодействия. Воспользуйтесь PolynomialFeatures, чтобы добавить попарные произведения и квадраты всех признаков. Обучите Ridge-регрессию (подберите гиперпараметр!) и посчитайте $R^2$ на тесте. Сильно ли изменилось качество?

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
# pipe = make_pipeline(PolynomialFeatures(2), Ridge())

# %%
poly = PolynomialFeatures(2)

# %%
x_train_poly = poly.fit_transform(x_train)

# %%
gs = GridSearchCV(Ridge(), grid, scoring='r2', cv = 5, return_train_score=True)

# %%
gs.fit(x_train_poly, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': array([-13.81551056, -13.53640933, -13.25730811, -12.97820689,
#        -12.69910566, -12.42000444, -12.14090322, -11.86180199,
#        -11.58270077, -11.30359955, -11.02449832, -10.7453971 ,
#        -10.46629588, -10.18719465,  -9.90809343,  -9.62899221,
#         -9.34989098,  -9.07078976,  -8.79168854,  -8.51258731,
#         -8.23348609,  -7.95438487,  -7.6752836...
#          6.27977753,   6.55887875,   6.83797997,   7.1170812 ,
#          7.39618242,   7.67528364,   7.95438487,   8.23348609,
#          8.51258731,   8.79168854,   9.07078976,   9.34989098,
#          9.62899221,   9.90809343,  10.18719465,  10.46629588,
#         10.7453971 ,  11.02449832,  11.30359955,  11.58270077,
#         11.86180199,  12.14090322,  12.42000444,  12.69910566,
#         12.97820689,  13.25730811,  13.53640933,  13.81551056])},
#              return_train_score=True, scoring='r2')

# %%
gs.best_score_
# Out:
# 0.798366335785923

# %%
gs.best_estimator_
# Out:
# Ridge(alpha=13.815510557964274)

# %% [markdown]
# __Задание 5.__ Оптимальная архитектура, анализ.
#
# При помощи `Pipeline` и `GridSearchCV` выберите оптимальную архитектуру, комбинируя различные методы масштабирования, степень полинома в `PolynomialFeatures`, а также регуляризаторы. Для `Lasso` поставьте максимальное количество итераций больше значения по умолчанию, чтобы оптимизация сошлась.

# %%
for lin in (Ridge(), Lasso(max_iter=3000)):
    for scaler in (StandardScaler(), MinMaxScaler()):
            pipe = make_pipeline(PolynomialFeatures(2), 
                                 scaler,
                                 GridSearchCV(lin, grid, scoring='r2', cv = 5, return_train_score=True))
            pipe.fit(x_train, y_train)
            print('{} - {} - {}'.format(lin, scaler, pipe.score(x_test, y_test)))
# Out:
# Ridge() - StandardScaler() - 0.8493773140671135
# Ridge() - MinMaxScaler() - 0.8492825742859262
# Lasso() - StandardScaler() - 0.7713752345984444
# Lasso() - MinMaxScaler() - 0.7055523248796933

# %% [markdown]
# Для одной комбинаций метода масштабирования и линейной регрессии постройте зависимость метрики $R^2$ на кросс-валидации (`GridSearchCV.cv_results_['mean_test_score']`) от значения параметра регуляризации для различных степеней полиномов в `PolynomialFeatures`.

# %%
#  Your code here
# ...

# %% [markdown]
# При каких значениях происходит переобучение? А недообучение? Почему?

# %% [markdown]
# __Ответ:__
